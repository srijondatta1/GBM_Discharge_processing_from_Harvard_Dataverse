# %%
# ================================================================================================
#   PYTHON SCRIPT: HIGH-PERFORMANCE NETCDF TIME-SERIES EXTRACTOR (SEQUENTIAL & RESILIENT)
# ================================================================================================

# ================================================================================================
#   STEP 1: IMPORT MODULES
# ================================================================================================

import xarray as xr
import pandas as pd
import numpy as np
import pathlib
import time
import shutil
import os
import glob
from typing import Dict, Any, List, Tuple
from tqdm import tqdm # Used for clear status bars

# ================================================================================================
#   STEP 2: USER-EDITABLE SETTINGS (MAXIMUM FLEXIBILITY)
# ================================================================================================

# --- A. FILE PATHS & DIRECTORIES ---

# 1. INPUT DIRECTORY (The folder containing all your NetCDF files)
NC_INPUT_DIRECTORY: str = "Observed_daily_dscharge/Raw_netcdf"

# 2. POINT FILE PATH (The CSV containing the longitudes and latitudes of the outlets/subbasins)
POINT_CSV_FILE_PATH: str = "Outlet_subbasin.csv"

# --- DERIVED OUTPUT PATHS (DO NOT EDIT THESE) ---
INPUT_ROOT_DIR = pathlib.Path(NC_INPUT_DIRECTORY)
# Temporary directory for yearly extracted CSVs (will be created/deleted)
YEARLY_DATA_DIR: str = str(INPUT_ROOT_DIR / "01_Intermediate_Yearly_CSVs")
# Final directory for the single, merged time-series CSV for each point
FINAL_MERGED_OUTPUT_DIR: str = str(INPUT_ROOT_DIR / "02_Final_Merged_Streamflow")

# --- B. NETCDF FILE SELECTION ---
# Pattern to match NetCDF files (e.g., "*.nc" for all files, or "ERA5L_*.nc")
NC_FILE_PATTERN: str = "*.nc"
# Process a subset of files: If empty list [], all files matching the pattern will be processed.
# Set this to [] to process all files, or keep your example ["ERA5L_9km_BG_daily_streamflow_1951.nc", "ERA5L_9km_BG_daily_streamflow_1952.nc"]to test the single-file scenario:
NC_FILES_TO_PROCESS: List[str] = [] # Example filter

# --- C. INPUT DATA CONFIGURATION ---
# The field in your point CSV that uniquely identifies each subbasin/outlet
POINT_ID_FIELD: str = "NAME"
# Column names in the point CSV for coordinates (NetCDF expects 'lon' and 'lat')
LONGITUDE_FIELD: str = "LONG"
LATITUDE_FIELD: str = "LAT"
# The data variable to extract from the NetCDF file
NETCDF_VARIABLE: str = "flw"

# --- D. OUTPUT DATA CONFIGURATION ---
# Defines the column names for the output CSVs
OUTPUT_COLUMN_NAMES: Dict[str, str] = {"time": "DATE", "value": "DISCHARGE"}

# --- E. RESILIENCE & CLEANUP ---
# If True, files in FINAL_MERGED_OUTPUT_DIR will be overwritten.
# If False, the script will enable a smart-resume feature (with data integrity check).
OVERWRITE_EXISTING: bool = False
# If True, the temporary YEARLY_DATA_DIR is deleted after a successful run.
CLEANUP_YEARLY_DIR: bool = False

# Global dictionary to cache datasets in the main thread's memory.
worker_datasets: Dict[str, xr.Dataset] = {}

# ================================================================================================
#   STEP 3: CORE WORKER FUNCTIONS (SEQUENTIAL PROCESSING LOGIC)
# ================================================================================================

def open_nc_dataset_cached(nc_file_path: str) -> xr.Dataset:
    """
    Opens a NetCDF dataset using a thread-local cache.
    This prevents redundant opening of the same file.
    """
    global worker_datasets
    if nc_file_path not in worker_datasets:
        worker_datasets[nc_file_path] = xr.open_dataset(nc_file_path, engine='netcdf4')
    return worker_datasets[nc_file_path]

def calculate_expected_length(nc_file_paths: List[str]) -> int:
    """
    Calculates the total expected number of time steps (records)
    from all NetCDF files being processed.
    """
    total_records = 0
    for nc_path in nc_file_paths:
        try:
            ds = open_nc_dataset_cached(nc_path)
            total_records += len(ds['time'])
        except Exception as e:
            return -1 # Signal failure/unknown length
    return total_records

def extraction_worker(point_data: pd.Series, nc_file_path: str) -> Tuple[bool, str, str]:
    """
    Sequential worker function for Phase 1: Extracts time-series for one point from one NetCDF file.
    Returns: success, point_id, status_message
    """
    point_id = str(point_data[POINT_ID_FIELD])
    nc_file_name = pathlib.Path(nc_file_path).name
    nc_stem = pathlib.Path(nc_file_name).stem
    
    try:
        lon = point_data[LONGITUDE_FIELD]
        lat = point_data[LATITUDE_FIELD]

        # Determine output path for the yearly intermediate file
        yearly_dir = pathlib.Path(YEARLY_DATA_DIR) / nc_stem
        yearly_dir.mkdir(parents=True, exist_ok=True)
        yearly_output_path = yearly_dir / f"{point_id}.csv"

        # Skip if already exists
        if not OVERWRITE_EXISTING and yearly_output_path.exists():
            # Return 'SKIPPED' action
            return True, point_id, f"{point_id} & {nc_stem}.csv | Status: SUCCESS | Action: SKIPPED"

        # 1. Access cached dataset
        ds = open_nc_dataset_cached(nc_file_path)

        # 2. Extract data using nearest-neighbor lookup
        data_slice = ds[NETCDF_VARIABLE].sel(
            lon=lon,
            lat=lat,
            method='nearest'
        )

        # 3. Convert to Pandas DataFrame and save intermediate CSV
        df = data_slice.to_dataframe(NETCDF_VARIABLE).reset_index()
        df = df.rename(columns={'time': 'time', NETCDF_VARIABLE: 'value'})
        df[['time', 'value']].to_csv(yearly_output_path, index=False)

        # Return 'EXTRACTED' action
        return True, point_id, f"{point_id} & {nc_stem}.csv | Status: SUCCESS | Action: EXTRACTED"

    except Exception as e:
        # Return 'FAILED' action
        return False, point_id, f"{point_id} & {nc_stem}.csv | Status: FAILURE | Action: {e.__class__.__name__}"

def merge_worker(point_id: str, nc_file_stems: List[str], expected_total_records: int) -> Tuple[bool, str, str]:
    """
    Sequential worker function for Phase 2: Merges all yearly CSVs for one point into a single file.
    """
    final_output_path = pathlib.Path(FINAL_MERGED_OUTPUT_DIR) / f"{point_id}.csv"

    # Check for smart resume (OVERWRITE_EXISTING is False)
    if not OVERWRITE_EXISTING and final_output_path.exists():
        try:
            # --- ROBUST CHECK: Verify File Record Count ---
            if expected_total_records > 0:
                with open(final_output_path, 'r', encoding='utf-8') as f:
                    actual_lines = sum(1 for line in f)
                    
                expected_lines = expected_total_records + 1 # +1 for header
                
                if actual_lines == expected_lines:
                    return True, point_id, f"Skipped (Record count verified: {final_output_path.name})"
            
        except Exception:
            # If resume check fails, proceed to merge/overwrite
            pass

    try:
        yearly_dfs = []
        for stem in nc_file_stems:
            yearly_path = pathlib.Path(YEARLY_DATA_DIR) / stem / f"{point_id}.csv"
            if yearly_path.exists():
                df = pd.read_csv(yearly_path, parse_dates=['time'], dtype={'value': np.float64})
                yearly_dfs.append(df)

        if not yearly_dfs:
            return False, point_id, f"Error: No yearly data found for Point ID {point_id}."

        # Concatenate, sort by date, and finalize the DataFrame
        merged_df = pd.concat(yearly_dfs, ignore_index=True)
        merged_df = merged_df.sort_values(by='time').drop_duplicates(subset='time', keep='last')

        # Final formatting and save
        merged_df.rename(columns=OUTPUT_COLUMN_NAMES, inplace=True)
        final_output_path.parent.mkdir(parents=True, exist_ok=True)
        merged_df.to_csv(final_output_path, index=False)
        
        # Post-merge safety check for data integrity
        if expected_total_records > 0 and len(merged_df) != expected_total_records:
             return False, point_id, f"Merge completed but record count mismatch: Expected {expected_total_records}, Found {len(merged_df)}"

        return True, point_id, str(final_output_path)

    except Exception as e:
        return False, point_id, f"Error merging data: {e}"

# ================================================================================================
#   STEP 4: MAIN WORKFLOW PHASES (SEQUENTIAL EXECUTION)
# ================================================================================================

def format_bytes(size_in_bytes: int) -> str:
    """Converts bytes to a human-readable format (MB or KB)."""
    if size_in_bytes is None or size_in_bytes < 0: return "N/A"
    if size_in_bytes >= 1048576: return f"{size_in_bytes / 1048576:.2f} MB"
    elif size_in_bytes >= 1024: return f"{size_in_bytes / 1024:.2f} KB"
    else: return f"{size_in_bytes} Bytes"

def print_verification_report(report_data: List[Dict[str, str]]):
    """Prints the final verification report in the requested table format."""

    COL_WIDTHS = [45, 12, 9, 15] 

    print("\n\n✅ FINAL VERIFICATION REPORT")
    print("-" * (sum(COL_WIDTHS) + 9))
    header = f"{'File Name':<{COL_WIDTHS[0]}} | {'Size':>{COL_WIDTHS[1]}} | {'Status':<{COL_WIDTHS[2]}} | {'Action/Reason':<{COL_WIDTHS[3]}}"
    print(header)
    print("-" * (sum(COL_WIDTHS) + 9))

    for row in report_data:
        status_display = row['Status']
        action = row['Action'].upper()
        
        output_row = (
            f"{row['FileName']:<{COL_WIDTHS[0]}} | "
            f"{row['Size']:>{COL_WIDTHS[1]}} | "
            f"{status_display:<{COL_WIDTHS[2]}} | "
            f"{action:<{COL_WIDTHS[3]}}"
        )
        print(output_row)
    print("-" * (sum(COL_WIDTHS) + 9))

def prepare_data_and_files() -> Tuple[pd.DataFrame, List[str]]:
    """Loads points, finds NC files, and prepares the processing list."""

    points_df = pd.read_csv(POINT_CSV_FILE_PATH)
    points_df[POINT_ID_FIELD] = points_df[POINT_ID_FIELD].astype(str)
    print(f"Loaded {len(points_df)} points from {pathlib.Path(POINT_CSV_FILE_PATH).name}.")

    nc_input_dir = pathlib.Path(NC_INPUT_DIRECTORY)
    all_nc_files = glob.glob(str(nc_input_dir / NC_FILE_PATTERN))

    if NC_FILES_TO_PROCESS:
        nc_files = [f for f in all_nc_files if pathlib.Path(f).name in NC_FILES_TO_PROCESS]
    else:
        nc_files = all_nc_files
    nc_files.sort()

    # --- Input File Report ---
    print("\n" + "--- [ Task 1.1: Input NetCDF File Report ] ---")
    COL_WIDTHS = [45, 12, 10]
    print("-" * (sum(COL_WIDTHS) + 6))
    nc_header = f"{'File Name':<{COL_WIDTHS[0]}} | {'Records':>{COL_WIDTHS[1]}} | {'Status':<{COL_WIDTHS[2]}}"
    print(nc_header)
    print("-" * (sum(COL_WIDTHS) + 6))
    
    total_expected_records = 0
    for nc_path in nc_files:
        nc_file_name = pathlib.Path(nc_path).name
        try:
            ds = open_nc_dataset_cached(nc_path)
            num_records = len(ds['time'])
            total_expected_records += num_records
            status = "LOADED"
        except Exception:
            num_records = "ERROR"
            status = "FAILED"
            
        output_row = (
            f"{nc_file_name:<{COL_WIDTHS[0]}} | "
            f"{str(num_records):>{COL_WIDTHS[1]}} | "
            f"{status:<{COL_WIDTHS[2]}}"
        )
        print(output_row)

    print("-" * (sum(COL_WIDTHS) + 6))
    print(f"Total Expected Records (All Files): {total_expected_records}")
    print(f"Found {len(nc_files)} NetCDF files for processing.")

    # --- Smart Resume Filtering ---
    if not OVERWRITE_EXISTING:
        processed_ids = []
        if pathlib.Path(FINAL_MERGED_OUTPUT_DIR).exists():
            # Check for final file existence AND correct record count
            expected_lines = total_expected_records + 1 if total_expected_records > 0 else -1
            
            for file_path in pathlib.Path(FINAL_MERGED_OUTPUT_DIR).glob("*.csv"):
                if expected_lines > 0:
                    try:
                        with open(file_path, 'r', encoding='utf-8') as f:
                            actual_lines = sum(1 for line in f)
                        if actual_lines == expected_lines:
                             processed_ids.append(file_path.stem)
                    except Exception:
                         pass
                elif file_path.stat().st_size > 1024:
                     processed_ids.append(file_path.stem)


        processed_set = set(processed_ids)
        # Filter points for which the FINAL merged file is missing or invalid
        points_to_process = points_df[~points_df[POINT_ID_FIELD].astype(str).isin(processed_set)].copy()

        if len(points_to_process) < len(points_df):
            skipped_count = len(points_df) - len(points_to_process)
            print(f"Smart Resume Enabled: Skipping {skipped_count}/{len(points_df)} points for initial extraction.")
        else:
            print("Smart Resume: No valid final merged files found for initial skipping.")
    else:
        points_to_process = points_df.copy()

    return points_to_process, nc_files

def run_extraction_phase(points_to_process: pd.DataFrame, nc_files: List[str]) -> bool:
    """Phase 1: Extracts time-series data sequentially with real-time feedback."""
    print("\n" + "="*80)
    print("PHASE 1: SEQUENTIAL DATA EXTRACTION")
    print("="*80)

    extraction_tasks = []
    for index, point_data in points_to_process.iterrows():
        for nc_file_path in nc_files:
            extraction_tasks.append((point_data, nc_file_path))

    total_tasks = len(extraction_tasks)
    if total_tasks == 0:
        print("Sub-Process: No points or NC files to process. Skipping Phase 1.")
        return True

    print(f"Sub-Process: Initializing {total_tasks} extraction tasks for sequential execution...")
    
    # --- Real-Time Report Header ---
    print("\n✅ REAL-TIME EXTRACTION STATUS")
    print("-" * 80)
    print("| {:<50} | {:<10} | {:<14}".format('Point ID & File Stem', 'Status', 'Action'))
    print("-" * 80)
    
    successful_tasks = 0
    failed_tasks = 0
    
    # We use the tqdm description for the dynamic update
    with tqdm(extraction_tasks, total=total_tasks, desc="Extraction Progress", unit="task", leave=True) as pbar:
        for task in pbar:
            success, point_id, message = extraction_worker(*task)
            
            # Message format: "Subbasin_X & ERA5L_Y.csv | Status: SUCCESS | Action: SKIPPED"
            # Update the description bar with the last completed action
            pbar.set_description(f"Extraction Progress | LAST: {message}")
            
            if success:
                successful_tasks += 1
            else:
                failed_tasks += 1

    if failed_tasks > 0:
        print(f"\n⚠️ Phase 1 completed with {failed_tasks} failed tasks. Check intermediate files/logs.")
    else:
        print(f"\n✅ Phase 1 successfully completed. Total tasks: {successful_tasks}.")

    return failed_tasks == 0

def run_merging_phase(unique_point_ids: np.ndarray, nc_files: List[str]) -> bool:
    """Phase 2: Merges yearly CSV files for each point sequentially, with clean output."""
    print("\n" + "="*80)
    print("PHASE 2: SEQUENTIAL TIME-SERIES MERGING")
    print("="*80)

    yearly_data_path = pathlib.Path(YEARLY_DATA_DIR)
    if not yearly_data_path.exists():
        print("Sub-Process: Intermediate yearly data directory does not exist. Skipping Phase 2.")
        return True

    nc_file_stems = [pathlib.Path(f).stem for f in nc_files]
    
    expected_records = calculate_expected_length(nc_files)
    if expected_records > 0:
        print(f"Sub-Process: Calculated expected time steps: {expected_records} records.")
    else:
        print("Sub-Process: Could not determine expected time steps. Skipping robust record count check for merges.")

    merging_tasks = [(str(point_id), nc_file_stems, expected_records) for point_id in unique_point_ids]
    total_tasks = len(merging_tasks)

    if total_tasks == 0:
        print("Sub-Process: No points require merging. Skipping Phase 2.")
        return True

    print(f"Sub-Process: Initializing {total_tasks} merging tasks for sequential execution...")

    successful_merges = 0
    failed_merges = 0

    for task in tqdm(merging_tasks, total=total_tasks, desc="Merging Progress"):
        success, point_id, message = merge_worker(*task)
        if success:
            if not message.startswith("Skipped"):
                successful_merges += 1
        else:
            failed_merges += 1

    if failed_merges > 0:
        print(f"\n⚠️ Phase 2 completed with {failed_merges} failed merge tasks. Details will be in the Verification Report.")
    else:
        print(f"\n✅ Phase 2 successfully completed. Merged {successful_merges} new files.")

    return failed_merges == 0

def run_verification_phase(points_df: pd.DataFrame, nc_files: List[str]):
    """Phase 3: Final verification and reporting."""
    print("\n" + "="*80)
    print("PHASE 3: FINAL VERIFICATION & REPORTING")
    print("="*80)

    report_data = []
    total_input_points = len(points_df)
    final_output_dir = pathlib.Path(FINAL_MERGED_OUTPUT_DIR)
    
    if not final_output_dir.exists():
        print("Sub-Process: Final output directory does not exist. Cannot run verification.")
        return report_data

    all_point_ids = set(points_df[POINT_ID_FIELD].astype(str).unique())
    found_files = {file_path.stem: file_path for file_path in final_output_dir.glob("*.csv")}
        
    expected_records = calculate_expected_length(nc_files)
    expected_lines = expected_records + 1 if expected_records > 0 else -1

    for point_id in all_point_ids:
        file_name = f"{point_id}.csv"
        file_path = found_files.get(point_id)

        status = "FAILURE"
        action = "NOT FOUND"
        file_size_str = "0 Bytes"

        if file_path and file_path.exists():
            try:
                size_bytes = file_path.stat().st_size
                file_size_str = format_bytes(size_bytes)
                
                if size_bytes > 1024:
                    status = "SUCCESS"
                    action = "MERGED" 
                    
                    if expected_lines > 0:
                        with open(file_path, 'r', encoding='utf-8') as f:
                            actual_lines = sum(1 for line in f)
                        
                        if actual_lines == expected_lines:
                            action = "VERIFIED"
                        else:
                            status = "WARNING"
                            action = f"INCOMPLETE ({actual_lines}/{expected_lines})"
                            
                else:
                    status = "FAILURE"
                    action = "ZERO SIZE"
                    
            except Exception as e:
                status = "ERROR"
                action = f"READ FAIL ({e.__class__.__name__})"
                
        report_data.append({
            "FileName": file_name,
            "Size": file_size_str,
            "Status": status,
            "Action": action
        })
        
    print("\nSub-Process: Internal Completeness Checks...")
    final_file_count = sum(1 for d in report_data if d['Status'] == "SUCCESS" or d['Action'] == "VERIFIED")

    if final_file_count == total_input_points:
        status_text = "✅ COMPLETE"
        message = f"All {total_input_points} input points have a final merged/verified file."
    else:
        status_text = "⚠️ PARTIAL"
        message = f"Found {final_file_count}/{total_input_points} final merged/verified files."

    print(f"  - Completeness Status: {status_text}")
    print(f"  - {message}")
    
    return report_data

# ================================================================================================
#   STEP 5: MAIN EXECUTION FLOW
# ================================================================================================

def main():
    """The main control function for the entire workflow."""

    overall_start_time = time.time()

    print("\n" + "#"*80)
    print("           UNIFIED NETCDF TIME-SERIES EXTRACTION AND MERGING WORKFLOW")
    print("#"*80)
    
    try:
        # --- Task 1: Preparation ---
        print("\n" + "--- [ Task 1: Initialization and File Discovery ] ---")
        points_to_process, nc_files = prepare_data_and_files() 

        # --- Task 2: Run Extraction (Phase 1) ---
        run_extraction_phase(points_to_process, nc_files)

        # --- Task 3: Run Merging (Phase 2) ---
        points_df_all = pd.read_csv(POINT_CSV_FILE_PATH)
        all_point_ids = points_df_all[POINT_ID_FIELD].astype(str).unique()
        run_merging_phase(all_point_ids, nc_files)

        # --- Task 4: Verification and Cleanup (Phase 3) ---
        points_df_all = pd.read_csv(POINT_CSV_FILE_PATH)
        final_report_data = run_verification_phase(points_df_all, nc_files)
        
        # --- Task 5: Print Final Report ---
        if final_report_data:
            print_verification_report(final_report_data)

        if CLEANUP_YEARLY_DIR and pathlib.Path(YEARLY_DATA_DIR).exists():
            print(f"\n--- [ Task 6: Cleanup ] ---")
            shutil.rmtree(YEARLY_DATA_DIR)

    except Exception as e:
        print(f"\n\n{'='*80}\nFATAL ERROR: The workflow stopped unexpectedly.\nError Details: {e}\n{'='*80}")
        global worker_datasets
        worker_datasets.clear()
        return 

    # --- FINAL NOTIFICATION ---
    overall_end_time = time.time()
    print(f"\n\n{'='*80}")
    print("✅ ALL TASKS COMPLETE")
    print(f"Total elapsed time: {overall_end_time - overall_start_time:.2f} seconds.")
    print(f"Results saved to: {FINAL_MERGED_OUTPUT_DIR}")
    print('='*80)

if __name__ == "__main__":
    main()

# %% [raw]
# Output Preview
#
# ################################################################################
#            UNIFIED NETCDF TIME-SERIES EXTRACTION AND MERGING WORKFLOW
# ################################################################################
#
# --- [ Task 1: Initialization and File Discovery ] ---
# Loaded 415 points from Outlest_subbasin.csv.
#
# --- [ Task 1.1: Input NetCDF File Report ] ---
# -------------------------------------------------------------------------
# File Name                                     |      Records | Status
# -------------------------------------------------------------------------
# ERA5L_9km_BG_daily_streamflow_1951.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1952.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1953.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1954.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1955.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1956.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1957.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1958.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1959.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1960.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1961.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1962.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1963.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1964.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1965.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1966.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1967.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1968.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1969.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1970.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1971.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1972.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1973.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1974.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1975.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1976.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1977.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1978.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1979.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1980.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1981.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1982.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1983.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1984.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1985.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1986.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1987.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1988.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1989.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1990.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1991.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1992.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1993.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1994.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1995.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1996.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_1997.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1998.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_1999.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2000.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_2001.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2002.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2003.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2004.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_2005.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2006.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2007.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2008.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_2009.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2010.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2011.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2012.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_2013.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2014.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2015.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2016.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_2017.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2018.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2019.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2020.nc         |          366 | LOADED
# ERA5L_9km_BG_daily_streamflow_2021.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2022.nc         |          365 | LOADED
# ERA5L_9km_BG_daily_streamflow_2023.nc         |          365 | LOADED
# -------------------------------------------------------------------------
# Total Expected Records (All Files): 26663
# Found 73 NetCDF files for processing.
# Smart Resume: No valid final merged files found for initial skipping.
#
# ================================================================================
# PHASE 1: SEQUENTIAL DATA EXTRACTION
# ================================================================================
# Sub-Process: Initializing 30295 extraction tasks for sequential execution...
#
# ✅ REAL-TIME EXTRACTION STATUS
# --------------------------------------------------------------------------------
# | Point ID & File Stem                               | Status     | Action
# --------------------------------------------------------------------------------
#
# Extraction Progress | LAST: Subbasin_415 & ERA5L_9km_BG_daily_streamflow_2023.csv | Status: SUCCESS | Action: EXTRACTED
#
#
# ✅ Phase 1 successfully completed. Total tasks: 30295.
#
# ================================================================================
# PHASE 2: SEQUENTIAL TIME-SERIES MERGING
# ================================================================================
# Sub-Process: Calculated expected time steps: 26663 records.
# Sub-Process: Initializing 415 merging tasks for sequential execution...
#
# Merging Progress: 100%|██████████████████████████████████████████████████████████████| 415/415 [10:39<00:00,  1.54s/it]
#
#
# ✅ Phase 2 successfully completed. Merged 415 new files.
#
# ================================================================================
# PHASE 3: FINAL VERIFICATION & REPORTING
# ================================================================================
#
# Sub-Process: Internal Completeness Checks...
#   - Completeness Status: ✅ COMPLETE
#   - All 415 input points have a final merged/verified file.
#
#
# ✅ FINAL VERIFICATION REPORT
# ------------------------------------------------------------------------------------------
# File Name                                     |         Size | Status    | Action/Reason
# ------------------------------------------------------------------------------------------
# Subbasin_214.csv                              |    787.81 KB | SUCCESS   | VERIFIED
# Subbasin_254.csv                              |    721.64 KB | SUCCESS   | VERIFIED
# Subbasin_353.csv                              |    717.94 KB | SUCCESS   | VERIFIED
# Subbasin_262.csv                              |    730.53 KB | SUCCESS   | VERIFIED
# Subbasin_196.csv                              |    778.28 KB | SUCCESS   | VERIFIED
# Subbasin_367.csv                              |    711.10 KB | SUCCESS   | VERIFIED
# Subbasin_81.csv                               |    779.97 KB | SUCCESS   | VERIFIED
# Subbasin_30.csv                               |    789.72 KB | SUCCESS   | VERIFIED
# Subbasin_118.csv                              |    788.92 KB | SUCCESS   | VERIFIED
# Subbasin_134.csv                              |    788.37 KB | SUCCESS   | VERIFIED
# Subbasin_166.csv                              |    774.29 KB | SUCCESS   | VERIFIED
# Subbasin_6.csv                                |    777.78 KB | SUCCESS   | VERIFIED
# Subbasin_159.csv                              |    785.32 KB | SUCCESS   | VERIFIED
# Subbasin_224.csv                              |    777.09 KB | SUCCESS   | VERIFIED
# Subbasin_410.csv                              |    783.60 KB | SUCCESS   | VERIFIED
# Subbasin_98.csv                               |    785.32 KB | SUCCESS   | VERIFIED
# Subbasin_117.csv                              |    786.67 KB | SUCCESS   | VERIFIED
# Subbasin_76.csv                               |    776.23 KB | SUCCESS   | VERIFIED
# Subbasin_130.csv                              |    788.51 KB | SUCCESS   | VERIFIED
# Subbasin_49.csv                               |    787.59 KB | SUCCESS   | VERIFIED
# Subbasin_319.csv                              |    758.48 KB | SUCCESS   | VERIFIED
# Subbasin_59.csv                               |    748.58 KB | SUCCESS   | VERIFIED
# Subbasin_178.csv                              |    783.78 KB | SUCCESS   | VERIFIED
# Subbasin_124.csv                              |    787.09 KB | SUCCESS   | VERIFIED
# Subbasin_275.csv                              |    787.69 KB | SUCCESS   | VERIFIED
# Subbasin_15.csv                               |    779.36 KB | SUCCESS   | VERIFIED
# Subbasin_331.csv                              |    795.19 KB | SUCCESS   | VERIFIED
# Subbasin_342.csv                              |    711.10 KB | SUCCESS   | VERIFIED
# Subbasin_348.csv                              |    716.07 KB | SUCCESS   | VERIFIED
# Subbasin_368.csv                              |    786.68 KB | SUCCESS   | VERIFIED
# Subbasin_394.csv                              |    797.13 KB | SUCCESS   | VERIFIED
# Subbasin_216.csv                              |    786.78 KB | SUCCESS   | VERIFIED
# Subbasin_129.csv                              |    783.14 KB | SUCCESS   | VERIFIED
# Subbasin_107.csv                              |    776.72 KB | SUCCESS   | VERIFIED
# Subbasin_37.csv                               |    790.25 KB | SUCCESS   | VERIFIED
# Subbasin_183.csv                              |    731.96 KB | SUCCESS   | VERIFIED
# Subbasin_24.csv                               |    783.53 KB | SUCCESS   | VERIFIED
# Subbasin_87.csv                               |    784.05 KB | SUCCESS   | VERIFIED
# Subbasin_268.csv                              |    774.98 KB | SUCCESS   | VERIFIED
# Subbasin_354.csv                              |    708.21 KB | SUCCESS   | VERIFIED
# Subbasin_255.csv                              |    721.85 KB | SUCCESS   | VERIFIED
# Subbasin_141.csv                              |    748.58 KB | SUCCESS   | VERIFIED
# Subbasin_212.csv                              |    782.72 KB | SUCCESS   | VERIFIED
# Subbasin_293.csv                              |    784.59 KB | SUCCESS   | VERIFIED
# Subbasin_362.csv                              |    779.98 KB | SUCCESS   | VERIFIED
# Subbasin_400.csv                              |    783.00 KB | SUCCESS   | VERIFIED
# Subbasin_190.csv                              |    768.46 KB | SUCCESS   | VERIFIED
# Subbasin_249.csv                              |    783.25 KB | SUCCESS   | VERIFIED
# Subbasin_58.csv                               |    748.58 KB | SUCCESS   | VERIFIED
# Subbasin_388.csv                              |    786.42 KB | SUCCESS   | VERIFIED
# Subbasin_225.csv                              |    787.80 KB | SUCCESS   | VERIFIED
# Subbasin_39.csv                               |    785.62 KB | SUCCESS   | VERIFIED
# Subbasin_291.csv                              |    781.51 KB | SUCCESS   | VERIFIED
# Subbasin_351.csv                              |    714.56 KB | SUCCESS   | VERIFIED
# Subbasin_407.csv                              |    783.76 KB | SUCCESS   | VERIFIED
# Subbasin_23.csv                               |    790.25 KB | SUCCESS   | VERIFIED
# Subbasin_46.csv                               |    789.88 KB | SUCCESS   | VERIFIED
# Subbasin_315.csv                              |    785.66 KB | SUCCESS   | VERIFIED
# Subbasin_167.csv                              |    780.53 KB | SUCCESS   | VERIFIED
# Subbasin_66.csv                               |    767.26 KB | SUCCESS   | VERIFIED
# Subbasin_189.csv                              |    768.46 KB | SUCCESS   | VERIFIED
# Subbasin_53.csv                               |    785.75 KB | SUCCESS   | VERIFIED
# Subbasin_8.csv                                |    786.55 KB | SUCCESS   | VERIFIED
# Subbasin_50.csv                               |    788.92 KB | SUCCESS   | VERIFIED
# Subbasin_377.csv                              |    781.23 KB | SUCCESS   | VERIFIED
# Subbasin_147.csv                              |    780.33 KB | SUCCESS   | VERIFIED
# Subbasin_176.csv                              |    786.44 KB | SUCCESS   | VERIFIED
# Subbasin_83.csv                               |    779.75 KB | SUCCESS   | VERIFIED
# Subbasin_92.csv                               |    783.14 KB | SUCCESS   | VERIFIED
# Subbasin_382.csv                              |    710.66 KB | SUCCESS   | VERIFIED
# Subbasin_138.csv                              |    767.26 KB | SUCCESS   | VERIFIED
# Subbasin_231.csv                              |    787.19 KB | SUCCESS   | VERIFIED
# Subbasin_74.csv                               |    774.29 KB | SUCCESS   | VERIFIED
# Subbasin_51.csv                               |    783.97 KB | SUCCESS   | VERIFIED
# Subbasin_257.csv                              |    723.40 KB | SUCCESS   | VERIFIED
# Subbasin_415.csv                              |    701.55 KB | SUCCESS   | VERIFIED
# Subbasin_314.csv                              |    783.94 KB | SUCCESS   | VERIFIED
# Subbasin_218.csv                              |    794.42 KB | SUCCESS   | VERIFIED
# Subbasin_69.csv                               |    787.06 KB | SUCCESS   | VERIFIED
# Subbasin_412.csv                              |    796.67 KB | SUCCESS   | VERIFIED
# Subbasin_229.csv                              |    777.31 KB | SUCCESS   | VERIFIED
# Subbasin_355.csv                              |    712.26 KB | SUCCESS   | VERIFIED
# Subbasin_309.csv                              |    786.66 KB | SUCCESS   | VERIFIED
# Subbasin_285.csv                              |    758.96 KB | SUCCESS   | VERIFIED
# Subbasin_359.csv                              |    776.28 KB | SUCCESS   | VERIFIED
# Subbasin_230.csv                              |    787.55 KB | SUCCESS   | VERIFIED
# Subbasin_55.csv                               |    785.75 KB | SUCCESS   | VERIFIED
# Subbasin_320.csv                              |    779.62 KB | SUCCESS   | VERIFIED
# Subbasin_219.csv                              |    787.14 KB | SUCCESS   | VERIFIED
# Subbasin_10.csv                               |    779.85 KB | SUCCESS   | VERIFIED
# Subbasin_295.csv                              |    777.81 KB | SUCCESS   | VERIFIED
# Subbasin_378.csv                              |    765.27 KB | SUCCESS   | VERIFIED
# Subbasin_405.csv                              |    715.01 KB | SUCCESS   | VERIFIED
# Subbasin_369.csv                              |    786.89 KB | SUCCESS   | VERIFIED
# Subbasin_345.csv                              |    715.35 KB | SUCCESS   | VERIFIED
# Subbasin_321.csv                              |    781.65 KB | SUCCESS   | VERIFIED
# Subbasin_385.csv                              |    781.23 KB | SUCCESS   | VERIFIED
# Subbasin_72.csv                               |    770.12 KB | SUCCESS   | VERIFIED
# Subbasin_111.csv                              |    788.62 KB | SUCCESS   | VERIFIED
# Subbasin_79.csv                               |    780.53 KB | SUCCESS   | VERIFIED
# Subbasin_9.csv                                |    779.36 KB | SUCCESS   | VERIFIED
# Subbasin_125.csv                              |    788.62 KB | SUCCESS   | VERIFIED
# Subbasin_192.csv                              |    771.39 KB | SUCCESS   | VERIFIED
# Subbasin_25.csv                               |    784.77 KB | SUCCESS   | VERIFIED
# Subbasin_144.csv                              |    768.06 KB | SUCCESS   | VERIFIED
# Subbasin_151.csv                              |    787.09 KB | SUCCESS   | VERIFIED
# Subbasin_391.csv                              |    776.28 KB | SUCCESS   | VERIFIED
# Subbasin_116.csv                              |    786.67 KB | SUCCESS   | VERIFIED
# Subbasin_86.csv                               |    782.73 KB | SUCCESS   | VERIFIED
# Subbasin_258.csv                              |    728.40 KB | SUCCESS   | VERIFIED
# Subbasin_411.csv                              |    705.62 KB | SUCCESS   | VERIFIED
# Subbasin_217.csv                              |    789.25 KB | SUCCESS   | VERIFIED
# Subbasin_157.csv                              |    750.58 KB | SUCCESS   | VERIFIED
# Subbasin_191.csv                              |    768.46 KB | SUCCESS   | VERIFIED
# Subbasin_414.csv                              |    796.67 KB | SUCCESS   | VERIFIED
# Subbasin_172.csv                              |    783.42 KB | SUCCESS   | VERIFIED
# Subbasin_302.csv                              |    780.69 KB | SUCCESS   | VERIFIED
# Subbasin_13.csv                               |    788.54 KB | SUCCESS   | VERIFIED
# Subbasin_398.csv                              |    779.06 KB | SUCCESS   | VERIFIED
# Subbasin_251.csv                              |    788.18 KB | SUCCESS   | VERIFIED
# Subbasin_283.csv                              |    780.22 KB | SUCCESS   | VERIFIED
# Subbasin_373.csv                              |    717.94 KB | SUCCESS   | VERIFIED
# Subbasin_123.csv                              |    784.46 KB | SUCCESS   | VERIFIED
# Subbasin_333.csv                              |    787.86 KB | SUCCESS   | VERIFIED
# Subbasin_139.csv                              |    747.77 KB | SUCCESS   | VERIFIED
# Subbasin_71.csv                               |    769.16 KB | SUCCESS   | VERIFIED
# Subbasin_395.csv                              |    787.05 KB | SUCCESS   | VERIFIED
# Subbasin_228.csv                              |    771.81 KB | SUCCESS   | VERIFIED
# Subbasin_82.csv                               |    787.65 KB | SUCCESS   | VERIFIED
# Subbasin_227.csv                              |    785.59 KB | SUCCESS   | VERIFIED
# Subbasin_96.csv                               |    784.91 KB | SUCCESS   | VERIFIED
# Subbasin_386.csv                              |    779.98 KB | SUCCESS   | VERIFIED
# Subbasin_114.csv                              |    785.62 KB | SUCCESS   | VERIFIED
# Subbasin_7.csv                                |    783.97 KB | SUCCESS   | VERIFIED
# Subbasin_338.csv                              |    708.21 KB | SUCCESS   | VERIFIED
# Subbasin_280.csv                              |    780.40 KB | SUCCESS   | VERIFIED
# Subbasin_383.csv                              |    786.42 KB | SUCCESS   | VERIFIED
# Subbasin_392.csv                              |    785.15 KB | SUCCESS   | VERIFIED
# Subbasin_329.csv                              |    730.53 KB | SUCCESS   | VERIFIED
# Subbasin_374.csv                              |    714.96 KB | SUCCESS   | VERIFIED
# Subbasin_241.csv                              |    774.96 KB | SUCCESS   | VERIFIED
# Subbasin_271.csv                              |    758.96 KB | SUCCESS   | VERIFIED
# Subbasin_406.csv                              |    715.03 KB | SUCCESS   | VERIFIED
# Subbasin_381.csv                              |    711.67 KB | SUCCESS   | VERIFIED
# Subbasin_210.csv                              |    779.47 KB | SUCCESS   | VERIFIED
# Subbasin_270.csv                              |    758.48 KB | SUCCESS   | VERIFIED
# Subbasin_78.csv                               |    778.14 KB | SUCCESS   | VERIFIED
# Subbasin_33.csv                               |    789.72 KB | SUCCESS   | VERIFIED
# Subbasin_38.csv                               |    789.88 KB | SUCCESS   | VERIFIED
# Subbasin_361.csv                              |    779.06 KB | SUCCESS   | VERIFIED
# Subbasin_180.csv                              |    786.44 KB | SUCCESS   | VERIFIED
# Subbasin_132.csv                              |    785.62 KB | SUCCESS   | VERIFIED
# Subbasin_363.csv                              |    781.18 KB | SUCCESS   | VERIFIED
# Subbasin_263.csv                              |    729.38 KB | SUCCESS   | VERIFIED
# Subbasin_57.csv                               |    747.77 KB | SUCCESS   | VERIFIED
# Subbasin_182.csv                              |    794.42 KB | SUCCESS   | VERIFIED
# Subbasin_89.csv                               |    782.12 KB | SUCCESS   | VERIFIED
# Subbasin_122.csv                              |    782.22 KB | SUCCESS   | VERIFIED
# Subbasin_239.csv                              |    788.18 KB | SUCCESS   | VERIFIED
# Subbasin_413.csv                              |    701.55 KB | SUCCESS   | VERIFIED
# Subbasin_40.csv                               |    788.54 KB | SUCCESS   | VERIFIED
# Subbasin_184.csv                              |    785.03 KB | SUCCESS   | VERIFIED
# Subbasin_94.csv                               |    783.00 KB | SUCCESS   | VERIFIED
# Subbasin_136.csv                              |    766.40 KB | SUCCESS   | VERIFIED
# Subbasin_402.csv                              |    714.56 KB | SUCCESS   | VERIFIED
# Subbasin_42.csv                               |    786.06 KB | SUCCESS   | VERIFIED
# Subbasin_272.csv                              |    775.65 KB | SUCCESS   | VERIFIED
# Subbasin_401.csv                              |    714.48 KB | SUCCESS   | VERIFIED
# Subbasin_344.csv                              |    712.26 KB | SUCCESS   | VERIFIED
# Subbasin_222.csv                              |    771.39 KB | SUCCESS   | VERIFIED
# Subbasin_193.csv                              |    771.81 KB | SUCCESS   | VERIFIED
# Subbasin_343.csv                              |    711.67 KB | SUCCESS   | VERIFIED
# Subbasin_164.csv                              |    776.23 KB | SUCCESS   | VERIFIED
# Subbasin_17.csv                               |    780.12 KB | SUCCESS   | VERIFIED
# Subbasin_396.csv                              |    783.27 KB | SUCCESS   | VERIFIED
# Subbasin_77.csv                               |    776.72 KB | SUCCESS   | VERIFIED
# Subbasin_2.csv                                |    783.51 KB | SUCCESS   | VERIFIED
# Subbasin_47.csv                               |    794.74 KB | SUCCESS   | VERIFIED
# Subbasin_168.csv                              |    750.78 KB | SUCCESS   | VERIFIED
# Subbasin_20.csv                               |    787.59 KB | SUCCESS   | VERIFIED
# Subbasin_102.csv                              |    784.05 KB | SUCCESS   | VERIFIED
# Subbasin_304.csv                              |    786.54 KB | SUCCESS   | VERIFIED
# Subbasin_330.csv                              |    784.86 KB | SUCCESS   | VERIFIED
# Subbasin_403.csv                              |    783.00 KB | SUCCESS   | VERIFIED
# Subbasin_347.csv                              |    714.96 KB | SUCCESS   | VERIFIED
# Subbasin_14.csv                               |    788.39 KB | SUCCESS   | VERIFIED
# Subbasin_252.csv                              |    718.29 KB | SUCCESS   | VERIFIED
# Subbasin_308.csv                              |    721.64 KB | SUCCESS   | VERIFIED
# Subbasin_313.csv                              |    778.79 KB | SUCCESS   | VERIFIED
# Subbasin_67.csv                               |    768.06 KB | SUCCESS   | VERIFIED
# Subbasin_85.csv                               |    786.28 KB | SUCCESS   | VERIFIED
# Subbasin_152.csv                              |    787.06 KB | SUCCESS   | VERIFIED
# Subbasin_61.csv                               |    750.78 KB | SUCCESS   | VERIFIED
# Subbasin_287.csv                              |    787.67 KB | SUCCESS   | VERIFIED
# Subbasin_390.csv                              |    783.27 KB | SUCCESS   | VERIFIED
# Subbasin_105.csv                              |    782.50 KB | SUCCESS   | VERIFIED
# Subbasin_288.csv                              |    787.86 KB | SUCCESS   | VERIFIED
# Subbasin_261.csv                              |    730.21 KB | SUCCESS   | VERIFIED
# Subbasin_133.csv                              |    783.00 KB | SUCCESS   | VERIFIED
# Subbasin_221.csv                              |    786.57 KB | SUCCESS   | VERIFIED
# Subbasin_45.csv                               |    786.06 KB | SUCCESS   | VERIFIED
# Subbasin_137.csv                              |    784.91 KB | SUCCESS   | VERIFIED
# Subbasin_346.csv                              |    715.03 KB | SUCCESS   | VERIFIED
# Subbasin_70.csv                               |    788.51 KB | SUCCESS   | VERIFIED
# Subbasin_150.csv                              |    786.50 KB | SUCCESS   | VERIFIED
# Subbasin_328.csv                              |    758.96 KB | SUCCESS   | VERIFIED
# Subbasin_380.csv                              |    786.48 KB | SUCCESS   | VERIFIED
# Subbasin_282.csv                              |    780.22 KB | SUCCESS   | VERIFIED
# Subbasin_91.csv                               |    782.50 KB | SUCCESS   | VERIFIED
# Subbasin_215.csv                              |    786.77 KB | SUCCESS   | VERIFIED
# Subbasin_5.csv                                |    777.07 KB | SUCCESS   | VERIFIED
# Subbasin_148.csv                              |    786.59 KB | SUCCESS   | VERIFIED
# Subbasin_372.csv                              |    779.70 KB | SUCCESS   | VERIFIED
# Subbasin_393.csv                              |    710.66 KB | SUCCESS   | VERIFIED
# Subbasin_203.csv                              |    778.76 KB | SUCCESS   | VERIFIED
# Subbasin_234.csv                              |    774.19 KB | SUCCESS   | VERIFIED
# Subbasin_277.csv                              |    778.79 KB | SUCCESS   | VERIFIED
# Subbasin_267.csv                              |    774.98 KB | SUCCESS   | VERIFIED
# Subbasin_306.csv                              |    718.29 KB | SUCCESS   | VERIFIED
# Subbasin_75.csv                               |    774.82 KB | SUCCESS   | VERIFIED
# Subbasin_153.csv                              |    766.04 KB | SUCCESS   | VERIFIED
# Subbasin_99.csv                               |    794.43 KB | SUCCESS   | VERIFIED
# Subbasin_243.csv                              |    786.78 KB | SUCCESS   | VERIFIED
# Subbasin_12.csv                               |    783.51 KB | SUCCESS   | VERIFIED
# Subbasin_350.csv                              |    714.56 KB | SUCCESS   | VERIFIED
# Subbasin_104.csv                              |    783.42 KB | SUCCESS   | VERIFIED
# Subbasin_163.csv                              |    785.42 KB | SUCCESS   | VERIFIED
# Subbasin_120.csv                              |    790.17 KB | SUCCESS   | VERIFIED
# Subbasin_389.csv                              |    786.68 KB | SUCCESS   | VERIFIED
# Subbasin_131.csv                              |    783.12 KB | SUCCESS   | VERIFIED
# Subbasin_162.csv                              |    768.06 KB | SUCCESS   | VERIFIED
# Subbasin_341.csv                              |    711.49 KB | SUCCESS   | VERIFIED
# Subbasin_335.csv                              |    779.88 KB | SUCCESS   | VERIFIED
# Subbasin_161.csv                              |    786.59 KB | SUCCESS   | VERIFIED
# Subbasin_90.csv                               |    791.44 KB | SUCCESS   | VERIFIED
# Subbasin_289.csv                              |    729.38 KB | SUCCESS   | VERIFIED
# Subbasin_246.csv                              |    785.03 KB | SUCCESS   | VERIFIED
# Subbasin_197.csv                              |    755.55 KB | SUCCESS   | VERIFIED
# Subbasin_290.csv                              |    781.51 KB | SUCCESS   | VERIFIED
# Subbasin_278.csv                              |    721.63 KB | SUCCESS   | VERIFIED
# Subbasin_119.csv                              |    779.75 KB | SUCCESS   | VERIFIED
# Subbasin_156.csv                              |    794.43 KB | SUCCESS   | VERIFIED
# Subbasin_409.csv                              |    783.60 KB | SUCCESS   | VERIFIED
# Subbasin_165.csv                              |    789.65 KB | SUCCESS   | VERIFIED
# Subbasin_207.csv                              |    783.25 KB | SUCCESS   | VERIFIED
# Subbasin_194.csv                              |    772.38 KB | SUCCESS   | VERIFIED
# Subbasin_101.csv                              |    786.98 KB | SUCCESS   | VERIFIED
# Subbasin_21.csv                               |    788.18 KB | SUCCESS   | VERIFIED
# Subbasin_100.csv                              |    786.41 KB | SUCCESS   | VERIFIED
# Subbasin_336.csv                              |    784.86 KB | SUCCESS   | VERIFIED
# Subbasin_22.csv                               |    779.85 KB | SUCCESS   | VERIFIED
# Subbasin_60.csv                               |    788.86 KB | SUCCESS   | VERIFIED
# Subbasin_274.csv                              |    769.23 KB | SUCCESS   | VERIFIED
# Subbasin_198.csv                              |    743.48 KB | SUCCESS   | VERIFIED
# Subbasin_256.csv                              |    721.63 KB | SUCCESS   | VERIFIED
# Subbasin_18.csv                               |    784.77 KB | SUCCESS   | VERIFIED
# Subbasin_95.csv                               |    784.46 KB | SUCCESS   | VERIFIED
# Subbasin_155.csv                              |    767.27 KB | SUCCESS   | VERIFIED
# Subbasin_317.csv                              |    777.81 KB | SUCCESS   | VERIFIED
# Subbasin_339.csv                              |    710.66 KB | SUCCESS   | VERIFIED
# Subbasin_371.csv                              |    777.92 KB | SUCCESS   | VERIFIED
# Subbasin_208.csv                              |    767.00 KB | SUCCESS   | VERIFIED
# Subbasin_387.csv                              |    715.35 KB | SUCCESS   | VERIFIED
# Subbasin_318.csv                              |    780.64 KB | SUCCESS   | VERIFIED
# Subbasin_292.csv                              |    779.88 KB | SUCCESS   | VERIFIED
# Subbasin_179.csv                              |    787.65 KB | SUCCESS   | VERIFIED
# Subbasin_265.csv                              |    769.01 KB | SUCCESS   | VERIFIED
# Subbasin_113.csv                              |    786.98 KB | SUCCESS   | VERIFIED
# Subbasin_248.csv                              |    782.72 KB | SUCCESS   | VERIFIED
# Subbasin_205.csv                              |    780.02 KB | SUCCESS   | VERIFIED
# Subbasin_26.csv                               |    777.78 KB | SUCCESS   | VERIFIED
# Subbasin_273.csv                              |    779.62 KB | SUCCESS   | VERIFIED
# Subbasin_35.csv                               |    787.45 KB | SUCCESS   | VERIFIED
# Subbasin_206.csv                              |    776.31 KB | SUCCESS   | VERIFIED
# Subbasin_187.csv                              |    754.96 KB | SUCCESS   | VERIFIED
# Subbasin_127.csv                              |    770.12 KB | SUCCESS   | VERIFIED
# Subbasin_237.csv                              |    787.19 KB | SUCCESS   | VERIFIED
# Subbasin_158.csv                              |    786.50 KB | SUCCESS   | VERIFIED
# Subbasin_236.csv                              |    786.57 KB | SUCCESS   | VERIFIED
# Subbasin_300.csv                              |    780.64 KB | SUCCESS   | VERIFIED
# Subbasin_84.csv                               |    774.82 KB | SUCCESS   | VERIFIED
# Subbasin_68.csv                               |    768.06 KB | SUCCESS   | VERIFIED
# Subbasin_232.csv                              |    785.59 KB | SUCCESS   | VERIFIED
# Subbasin_311.csv                              |    795.08 KB | SUCCESS   | VERIFIED
# Subbasin_188.csv                              |    755.55 KB | SUCCESS   | VERIFIED
# Subbasin_352.csv                              |    714.48 KB | SUCCESS   | VERIFIED
# Subbasin_408.csv                              |    779.70 KB | SUCCESS   | VERIFIED
# Subbasin_297.csv                              |    730.21 KB | SUCCESS   | VERIFIED
# Subbasin_340.csv                              |    710.66 KB | SUCCESS   | VERIFIED
# Subbasin_307.csv                              |    795.08 KB | SUCCESS   | VERIFIED
# Subbasin_145.csv                              |    748.58 KB | SUCCESS   | VERIFIED
# Subbasin_52.csv                               |    788.39 KB | SUCCESS   | VERIFIED
# Subbasin_41.csv                               |    794.74 KB | SUCCESS   | VERIFIED
# Subbasin_303.csv                              |    721.63 KB | SUCCESS   | VERIFIED
# Subbasin_32.csv                               |    782.79 KB | SUCCESS   | VERIFIED
# Subbasin_54.csv                               |    786.05 KB | SUCCESS   | VERIFIED
# Subbasin_44.csv                               |    780.12 KB | SUCCESS   | VERIFIED
# Subbasin_126.csv                              |    786.98 KB | SUCCESS   | VERIFIED
# Subbasin_244.csv                              |    778.28 KB | SUCCESS   | VERIFIED
# Subbasin_281.csv                              |    787.67 KB | SUCCESS   | VERIFIED
# Subbasin_29.csv                               |    786.53 KB | SUCCESS   | VERIFIED
# Subbasin_253.csv                              |    718.19 KB | SUCCESS   | VERIFIED
# Subbasin_171.csv                              |    787.45 KB | SUCCESS   | VERIFIED
# Subbasin_169.csv                              |    787.13 KB | SUCCESS   | VERIFIED
# Subbasin_240.csv                              |    789.25 KB | SUCCESS   | VERIFIED
# Subbasin_64.csv                               |    766.40 KB | SUCCESS   | VERIFIED
# Subbasin_379.csv                              |    781.18 KB | SUCCESS   | VERIFIED
# Subbasin_375.csv                              |    783.76 KB | SUCCESS   | VERIFIED
# Subbasin_334.csv                              |    784.59 KB | SUCCESS   | VERIFIED
# Subbasin_264.csv                              |    731.20 KB | SUCCESS   | VERIFIED
# Subbasin_93.csv                               |    783.12 KB | SUCCESS   | VERIFIED
# Subbasin_109.csv                              |    787.13 KB | SUCCESS   | VERIFIED
# Subbasin_310.csv                              |    728.40 KB | SUCCESS   | VERIFIED
# Subbasin_238.csv                              |    787.81 KB | SUCCESS   | VERIFIED
# Subbasin_364.csv                              |    767.78 KB | SUCCESS   | VERIFIED
# Subbasin_11.csv                               |    785.62 KB | SUCCESS   | VERIFIED
# Subbasin_360.csv                              |    778.08 KB | SUCCESS   | VERIFIED
# Subbasin_103.csv                              |    783.78 KB | SUCCESS   | VERIFIED
# Subbasin_397.csv                              |    787.05 KB | SUCCESS   | VERIFIED
# Subbasin_108.csv                              |    786.41 KB | SUCCESS   | VERIFIED
# Subbasin_325.csv                              |    758.96 KB | SUCCESS   | VERIFIED
# Subbasin_106.csv                              |    778.14 KB | SUCCESS   | VERIFIED
# Subbasin_324.csv                              |    781.65 KB | SUCCESS   | VERIFIED
# Subbasin_286.csv                              |    775.65 KB | SUCCESS   | VERIFIED
# Subbasin_160.csv                              |    789.45 KB | SUCCESS   | VERIFIED
# Subbasin_43.csv                               |    788.18 KB | SUCCESS   | VERIFIED
# Subbasin_245.csv                              |    788.04 KB | SUCCESS   | VERIFIED
# Subbasin_62.csv                               |    779.97 KB | SUCCESS   | VERIFIED
# Subbasin_370.csv                              |    795.49 KB | SUCCESS   | VERIFIED
# Subbasin_63.csv                               |    766.04 KB | SUCCESS   | VERIFIED
# Subbasin_384.csv                              |    786.89 KB | SUCCESS   | VERIFIED
# Subbasin_365.csv                              |    786.48 KB | SUCCESS   | VERIFIED
# Subbasin_4.csv                                |    783.53 KB | SUCCESS   | VERIFIED
# Subbasin_135.csv                              |    785.42 KB | SUCCESS   | VERIFIED
# Subbasin_154.csv                              |    782.12 KB | SUCCESS   | VERIFIED
# Subbasin_201.csv                              |    776.31 KB | SUCCESS   | VERIFIED
# Subbasin_88.csv                               |    803.46 KB | SUCCESS   | VERIFIED
# Subbasin_65.csv                               |    767.27 KB | SUCCESS   | VERIFIED
# Subbasin_31.csv                               |    790.25 KB | SUCCESS   | VERIFIED
# Subbasin_146.csv                              |    791.44 KB | SUCCESS   | VERIFIED
# Subbasin_312.csv                              |    721.85 KB | SUCCESS   | VERIFIED
# Subbasin_142.csv                              |    788.37 KB | SUCCESS   | VERIFIED
# Subbasin_174.csv                              |    786.98 KB | SUCCESS   | VERIFIED
# Subbasin_337.csv                              |    707.47 KB | SUCCESS   | VERIFIED
# Subbasin_294.csv                              |    731.20 KB | SUCCESS   | VERIFIED
# Subbasin_357.csv                              |    767.78 KB | SUCCESS   | VERIFIED
# Subbasin_195.csv                              |    774.19 KB | SUCCESS   | VERIFIED
# Subbasin_175.csv                              |    789.65 KB | SUCCESS   | VERIFIED
# Subbasin_376.csv                              |    707.47 KB | SUCCESS   | VERIFIED
# Subbasin_80.csv                               |    803.46 KB | SUCCESS   | VERIFIED
# Subbasin_112.csv                              |    788.19 KB | SUCCESS   | VERIFIED
# Subbasin_316.csv                              |    785.66 KB | SUCCESS   | VERIFIED
# Subbasin_19.csv                               |    790.25 KB | SUCCESS   | VERIFIED
# Subbasin_327.csv                              |    780.69 KB | SUCCESS   | VERIFIED
# Subbasin_226.csv                              |    772.38 KB | SUCCESS   | VERIFIED
# Subbasin_186.csv                              |    731.96 KB | SUCCESS   | VERIFIED
# Subbasin_276.csv                              |    721.63 KB | SUCCESS   | VERIFIED
# Subbasin_250.csv                              |    788.04 KB | SUCCESS   | VERIFIED
# Subbasin_36.csv                               |    787.45 KB | SUCCESS   | VERIFIED
# Subbasin_326.csv                              |    785.96 KB | SUCCESS   | VERIFIED
# Subbasin_220.csv                              |    787.14 KB | SUCCESS   | VERIFIED
# Subbasin_211.csv                              |    767.00 KB | SUCCESS   | VERIFIED
# Subbasin_366.csv                              |    777.92 KB | SUCCESS   | VERIFIED
# Subbasin_305.csv                              |    786.66 KB | SUCCESS   | VERIFIED
# Subbasin_296.csv                              |    728.73 KB | SUCCESS   | VERIFIED
# Subbasin_73.csv                               |    782.73 KB | SUCCESS   | VERIFIED
# Subbasin_209.csv                              |    777.31 KB | SUCCESS   | VERIFIED
# Subbasin_170.csv                              |    789.45 KB | SUCCESS   | VERIFIED
# Subbasin_259.csv                              |    728.73 KB | SUCCESS   | VERIFIED
# Subbasin_173.csv                              |    788.19 KB | SUCCESS   | VERIFIED
# Subbasin_140.csv                              |    782.22 KB | SUCCESS   | VERIFIED
# Subbasin_284.csv                              |    786.54 KB | SUCCESS   | VERIFIED
# Subbasin_1.csv                                |    777.07 KB | SUCCESS   | VERIFIED
# Subbasin_121.csv                              |    790.17 KB | SUCCESS   | VERIFIED
# Subbasin_199.csv                              |    774.96 KB | SUCCESS   | VERIFIED
# Subbasin_233.csv                              |    754.96 KB | SUCCESS   | VERIFIED
# Subbasin_298.csv                              |    780.40 KB | SUCCESS   | VERIFIED
# Subbasin_349.csv                              |    715.01 KB | SUCCESS   | VERIFIED
# Subbasin_177.csv                              |    788.92 KB | SUCCESS   | VERIFIED
# Subbasin_323.csv                              |    785.96 KB | SUCCESS   | VERIFIED
# Subbasin_260.csv                              |    728.73 KB | SUCCESS   | VERIFIED
# Subbasin_279.csv                              |    728.73 KB | SUCCESS   | VERIFIED
# Subbasin_181.csv                              |    788.08 KB | SUCCESS   | VERIFIED
# Subbasin_27.csv                               |    788.92 KB | SUCCESS   | VERIFIED
# Subbasin_110.csv                              |    788.08 KB | SUCCESS   | VERIFIED
# Subbasin_213.csv                              |    786.77 KB | SUCCESS   | VERIFIED
# Subbasin_301.csv                              |    783.94 KB | SUCCESS   | VERIFIED
# Subbasin_204.csv                              |    780.02 KB | SUCCESS   | VERIFIED
# Subbasin_48.csv                               |    786.55 KB | SUCCESS   | VERIFIED
# Subbasin_56.csv                               |    786.05 KB | SUCCESS   | VERIFIED
# Subbasin_404.csv                              |    711.49 KB | SUCCESS   | VERIFIED
# Subbasin_34.csv                               |    788.39 KB | SUCCESS   | VERIFIED
# Subbasin_202.csv                              |    778.76 KB | SUCCESS   | VERIFIED
# Subbasin_269.csv                              |    723.40 KB | SUCCESS   | VERIFIED
# Subbasin_235.csv                              |    777.09 KB | SUCCESS   | VERIFIED
# Subbasin_128.csv                              |    787.45 KB | SUCCESS   | VERIFIED
# Subbasin_247.csv                              |    779.47 KB | SUCCESS   | VERIFIED
# Subbasin_322.csv                              |    795.19 KB | SUCCESS   | VERIFIED
# Subbasin_332.csv                              |    787.69 KB | SUCCESS   | VERIFIED
# Subbasin_299.csv                              |    777.81 KB | SUCCESS   | VERIFIED
# Subbasin_223.csv                              |    768.46 KB | SUCCESS   | VERIFIED
# Subbasin_3.csv                                |    782.79 KB | SUCCESS   | VERIFIED
# Subbasin_149.csv                              |    780.33 KB | SUCCESS   | VERIFIED
# Subbasin_200.csv                              |    787.55 KB | SUCCESS   | VERIFIED
# Subbasin_143.csv                              |    784.73 KB | SUCCESS   | VERIFIED
# Subbasin_242.csv                              |    787.80 KB | SUCCESS   | VERIFIED
# Subbasin_28.csv                               |    788.39 KB | SUCCESS   | VERIFIED
# Subbasin_266.csv                              |    718.19 KB | SUCCESS   | VERIFIED
# Subbasin_356.csv                              |    765.27 KB | SUCCESS   | VERIFIED
# Subbasin_399.csv                              |    785.15 KB | SUCCESS   | VERIFIED
# Subbasin_358.csv                              |    714.56 KB | SUCCESS   | VERIFIED
# Subbasin_97.csv                               |    784.73 KB | SUCCESS   | VERIFIED
# Subbasin_115.csv                              |    786.28 KB | SUCCESS   | VERIFIED
# Subbasin_16.csv                               |    786.53 KB | SUCCESS   | VERIFIED
# Subbasin_185.csv                              |    743.48 KB | SUCCESS   | VERIFIED
# ------------------------------------------------------------------------------------------
#
#
# ================================================================================
# ✅ ALL TASKS COMPLETE
# Total elapsed time: 13754.33 seconds.
# Results saved to: Observed_daily_dscharge\Raw_netcdf\02_Final_Merged_Streamflow
# ================================================================================
